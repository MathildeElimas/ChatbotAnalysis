# %%
import pandas as pd

# %%
PATH = 'C:\\Users\\MathildeElimas\\Documents\\BYTEL\\Bot_Data\\'

# %%
riche_comment = pd.read_csv(PATH + 'bulkQuery_result_CaseRicheComment.csv', sep = ',')

# %%
riche_comment.head()
# Out:
#   CreatedBy.Profile.Name                                 CommentRichBody__c  \
# 0  Utilisateur Technique  {&quot;type&quot;:&quot;quickReplies&quot;,&qu...
# 1  Utilisateur Technique  {&quot;type&quot;:&quot;quickReplies&quot;,&qu...
# 2  Utilisateur Technique  {&quot;type&quot;:&quot;quickReplies&quot;,&qu...
# 3  Utilisateur Technique  {&quot;type&quot;:&quot;quickReplies&quot;,&qu...
# 4  Utilisateur Technique  {&quot;type&quot;:&quot;quickReplies&quot;,&qu...
#
#           ParentId__c
# 0  5001p00003imjqKAAQ
# 1  5001p00003imjqKAAQ
# 2  5001p00003imjqKAAQ
# 3  5001p00003imjqKAAQ
# 4  5001p00003imjqKAAQ

# %%
riche_comment['CommentRichBody__c'] = riche_comment['CommentRichBody__c'].str.replace('&quot;','\"')
riche_comment['CommentRichBody__c'] = riche_comment['CommentRichBody__c'].str.replace('null', 'None')
riche_comment['CommentRichBody__c'] = riche_comment['CommentRichBody__c'].str.replace('true', 'True')
riche_comment['CommentRichBody__c'] = riche_comment['CommentRichBody__c'].str.replace('false', 'False')

# %%
riche_comment['CommentRichBody__c'] = riche_comment['CommentRichBody__c'].apply(lambda x : eval(x) if x == x else None)

# %%
test = pd.json_normalize(riche_comment['CommentRichBody__c'])

# %%
riche_comment = pd.merge(riche_comment, test, left_index=True, right_index=True)

# %%
riche_comment.head()
# Out:
#   CreatedBy.Profile.Name                                 CommentRichBody__c  \
# 0  Utilisateur Technique  {'type': 'quickReplies', 'content': {'title': ...
# 1  Utilisateur Technique  {'type': 'quickReplies', 'content': {'title': ...
# 2  Utilisateur Technique  {'type': 'quickReplies', 'content': {'title': ...
# 3  Utilisateur Technique  {'type': 'quickReplies', 'content': {'title': ...
# 4  Utilisateur Technique  {'type': 'quickReplies', 'content': {'title': ...
#
#           ParentId__c          type isBot delay markdown  \
# 0  5001p00003imjqKAAQ  quickReplies  None  None     True
# 1  5001p00003imjqKAAQ  quickReplies  None  None     None
# 2  5001p00003imjqKAAQ  quickReplies  None  None     None
# 3  5001p00003imjqKAAQ  quickReplies  None  None     None
# 4  5001p00003imjqKAAQ  quickReplies  None  None     None
#
#                                        content.title  \
# 0  Voici des liens utiles qui peuvent vous orient...
# 1  Petite hésitation, vous voulez bien qu&#39;on ...
# 2  Pouvez-vous me confirmer que votre demande con...
# 3  Afin de vous dépanner, notre assistance sur le...
# 4               Souhaitez-vous le faire maintenant ?
#
#                                      content.buttons  \
# 0  [{'value': 'Problème Box/Tv', 'title': 'Problè...
# 1  [{'value': 'Oui', 'title': 'Oui'}, {'value': '...
# 2  [{'value': 'Oui', 'title': 'Oui'}, {'value': '...
# 3  [{'value': 'Oui', 'title': 'Oui'}, {'value': '...
# 4  [{'value': 'Oui', 'title': 'Oui'}, {'value': '...
#
#                                          value.title  \
# 0  Voici des liens utiles qui peuvent vous orient...
# 1        Petite hésitation, vous êtes à proximité ?
# 2                                                NaN
# 3  Afin de vous dépanner, notre assistance sur le...
# 4         Êtes-vous à proximité de vos équipements ?
#
#                                        value.buttons content.subtitle  \
# 0  [{'value': 'Problème Box/Tv', 'title': 'Problè...              NaN
# 1  [{'value': 'Oui', 'title': 'Oui'}, {'value': '...              NaN
# 2                                                NaN              NaN
# 3  [{'value': 'Oui', 'title': 'Oui'}, {'value': '...              NaN
# 4  [{'value': 'Oui', 'title': 'Oui'}, {'value': '...              NaN
#
#   content.imageUrl content value value.subtitle value.imageUrl
# 0              NaN     NaN   NaN            NaN            NaN
# 1              NaN     NaN   NaN            NaN            NaN
# 2              NaN     NaN   NaN            NaN            NaN
# 3              NaN     NaN   NaN            NaN            NaN
# 4              NaN     NaN   NaN            NaN            NaN

# %%
del(riche_comment['isBot'])
del(riche_comment['delay'])
del(riche_comment['CommentRichBody__c'])

# %%
riche_comment.rename(columns={'ParentId__c' :'ParentId'},
               inplace=True)

# %%
riche_comment.to_csv(PATH + 'bulkQuery_result_CaseRicheComment_propre.csv')
