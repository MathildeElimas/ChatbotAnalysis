# %%
import os
import matplotlib.pyplot as plt
import collections
import pickle

from data_processing import *

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, cross_validate, KFold
from sklearn.metrics import accuracy_score, balanced_accuracy_score
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\MathildeElimas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\MathildeElimas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\MathildeElimas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Using TensorFlow backend.

# %%
# PATH = os.path.dirname(os.getcwd()).replace('code','')
PATH = os.getcwd().replace('\\models', '') + '\\data'
method = 'tfidf'

# %%
intent, unique_intent, sentences = load_data(PATH + '\\intent_dialogues.csv')
# Out:
#                                             Sentence           Intent
# 0  Bonjour j'ai rendu mon équipement box est je n...  probleme_box_tv
# 1                                            Bonjour  probleme_box_tv
# 2                              Box internet en panne  probleme_box_tv
# 3  Plus de phone ni internet depuis plus ou moins...  probleme_box_tv
# 4  Bonjour j'ai la télécommande de ma box qui ne ...  probleme_box_tv

# %%
len(sentences)
# Out:
# 3400

# %%
intent_plot = dict(sorted(dict(collections.Counter(intent)).items(), key = lambda v : v[1], reverse = True))
plt.bar(intent_plot.keys(), intent_plot.values())
# Out:
# <BarContainer object of 3 artists>
# 2020-10-30 17:53:09,056 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2020-10-30 17:53:09,056 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,056 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# 2020-10-30 17:53:09,059 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,059 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal regular normal>) = 10.05
# 2020-10-30 17:53:09,059 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,060 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,060 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,061 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,061 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,062 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,062 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal regular normal>) = 10.05
# 2020-10-30 17:53:09,063 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,064 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# 2020-10-30 17:53:09,064 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal regular normal>) = 10.05
# 2020-10-30 17:53:09,065 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,066 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# 2020-10-30 17:53:09,066 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal regular normal>) = 10.05
# 2020-10-30 17:53:09,068 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,069 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,070 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,071 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal regular normal>) = 10.05
# 2020-10-30 17:53:09,071 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,072 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,072 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,073 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal regular normal>) = 10.05
# 2020-10-30 17:53:09,073 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,073 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,073 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,074 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,074 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal regular normal>) = 10.05
# 2020-10-30 17:53:09,074 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,075 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,076 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,076 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,076 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,077 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# 2020-10-30 17:53:09,077 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,077 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,078 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Californian FB' (CALIFI.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,078 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Gill Sans MT Condensed' (GILC____.TTF) normal normal 400 condensed>) = 10.25
# 2020-10-30 17:53:09,079 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bernard MT Condensed' (BERNHC.TTF) normal normal 400 condensed>) = 10.25
# 2020-10-30 17:53:09,080 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Dubai' (DUBAI-MEDIUM.TTF) normal normal medium normal>) = 10.145
# 2020-10-30 17:53:09,080 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Constantia' (constani.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,081 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Century' (CENTURY.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,081 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Cooper Black' (COOPBL.TTF) normal normal black normal>) = 10.525
# 2020-10-30 17:53:09,082 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bodoni MT' (BOD_I.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,083 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEB.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,083 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Tw Cen MT Condensed Extra Bold' (TCCEB.TTF) normal normal bold condensed>) = 10.535
# 2020-10-30 17:53:09,084 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Constantia' (constanz.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,084 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Snap ITC' (SNAP____.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,085 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Stencil' (STENCIL.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,085 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Berlin Sans FB' (BRLNSB.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,086 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,086 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Kunstler Script' (KUNSTLER.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,087 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Berlin Sans FB' (BRLNSB.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,088 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'High Tower Text' (HTOWERT.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,089 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Arial' (arialbi.ttf) italic normal 700 normal>) = 7.698636363636363
# 2020-10-30 17:53:09,089 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEO.TTF) oblique normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,090 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Leelawadee UI' (LeelUIsl.ttf) normal normal light normal>) = 10.24
# 2020-10-30 17:53:09,090 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Calibri' (calibrili.ttf) italic normal light normal>) = 11.24
# 2020-10-30 17:53:09,090 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bell MT' (BELLI.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,091 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Consolas' (consolai.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,091 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Microsoft JhengHei' (msjh.ttc) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,092 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bodoni MT' (BOD_CBI.TTF) italic normal 700 condensed>) = 11.535
# 2020-10-30 17:53:09,092 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Trebuchet MS' (trebucbi.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,092 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Calibri' (calibrili.ttf) italic normal light normal>) = 11.24
# 2020-10-30 17:53:09,093 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bodoni MT' (BOD_CB.TTF) normal normal 700 condensed>) = 10.535
# 2020-10-30 17:53:09,093 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Magneto' (MAGNETOB.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,093 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Yu Gothic' (YuGothM.ttc) normal normal medium normal>) = 10.145
# 2020-10-30 17:53:09,094 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Cambria' (cambriai.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,094 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Fax' (LFAXDI.TTF) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,094 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Palatino Linotype' (palai.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,095 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Segoe UI' (segoeuii.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,095 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Javanese Text' (javatext.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,096 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Tw Cen MT Condensed' (TCCB____.TTF) normal normal 700 condensed>) = 10.535
# 2020-10-30 17:53:09,096 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Calibri' (calibrib.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,097 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Script MT Bold' (SCRIPTBL.TTF) normal normal bold normal>) = 10.335
# 2020-10-30 17:53:09,098 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Tahoma' (tahomabd.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,098 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bauhaus 93' (BAUHS93.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,099 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Copperplate Gothic Light' (COPRGTL.TTF) normal normal light normal>) = 10.24
# 2020-10-30 17:53:09,099 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Sitka Small' (SitkaI.ttc) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,100 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Yu Gothic' (YuGothL.ttc) normal normal light normal>) = 10.24
# 2020-10-30 17:53:09,101 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Times New Roman' (times.ttf) normal normal roman normal>) = 10.145
# 2020-10-30 17:53:09,101 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Gill Sans MT' (GILI____.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,102 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Calibri' (calibril.ttf) normal normal light normal>) = 10.24
# 2020-10-30 17:53:09,102 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bodoni MT' (BOD_R.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,103 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Bright' (LBRITE.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,103 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Onyx' (ONYX.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,104 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Georgia' (georgiab.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,105 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Segoe UI Symbol' (seguisym.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,106 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Fax' (LFAXI.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,106 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Stencil' (STENCIL.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,107 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Wingdings 2' (WINGDNG2.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,107 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Webdings' (webdings.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,108 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Niagara Engraved' (NIAGENG.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,108 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Gill Sans MT' (GILB____.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,109 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Imprint MT Shadow' (IMPRISHA.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,109 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Perpetua' (PERB____.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,109 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Segoe UI' (segoeuiz.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,109 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Times New Roman' (timesi.ttf) italic normal roman normal>) = 11.145
# 2020-10-30 17:53:09,110 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Sans Typewriter' (LTYPE.TTF) normal normal regular normal>) = 10.05
# 2020-10-30 17:53:09,110 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Arial' (ARIALNBI.TTF) italic normal 700 condensed>) = 7.8986363636363635
# 2020-10-30 17:53:09,111 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEO.TTF) oblique normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,111 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Playbill' (PLAYBILL.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,111 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Vladimir Script' (VLADIMIR.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,112 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Edwardian Script ITC' (ITCEDSCR.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,113 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Wingdings 3' (WINGDNG3.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,113 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Candara' (Candarai.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,114 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Fax' (LFAX.TTF) normal normal regular normal>) = 10.05
# 2020-10-30 17:53:09,114 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Century Gothic' (GOTHICI.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,114 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Arial' (arialbi.ttf) italic normal 700 normal>) = 7.698636363636363
# 2020-10-30 17:53:09,115 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Franklin Gothic Book' (FRABK.TTF) normal normal book normal>) = 10.05
# 2020-10-30 17:53:09,115 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Segoe UI' (seguibl.ttf) normal normal black normal>) = 10.525
# 2020-10-30 17:53:09,116 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Showcard Gothic' (SHOWG.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,116 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Harrington' (HARNGTON.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,116 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Tw Cen MT' (TCMI____.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,117 - matplotlib.font_manager - DEBUG - findfont: score(<Font '
- matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Sans Unicode' (l_10646.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,200 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Yu Gothic' (YuGothR.ttc) normal normal regular normal>) = 10.05
# 2020-10-30 17:53:09,200 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Trebuchet MS' (trebucbd.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,201 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Monotype Corsiva' (MTCORSVA.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,201 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Dubai' (DUBAI-LIGHT.TTF) normal normal light normal>) = 10.24
# 2020-10-30 17:53:09,201 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Rockwell' (ROCKBI.TTF) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,202 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Microsoft YaHei' (msyhbd.ttc) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,202 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Rockwell' (ROCKI.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,203 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bodoni MT' (BOD_CBI.TTF) italic normal 700 condensed>) = 11.535
# 2020-10-30 17:53:09,203 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Fax' (LFAXDI.TTF) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,204 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Rockwell Condensed' (ROCCB___.TTF) normal normal 700 condensed>) = 10.535
# 2020-10-30 17:53:09,204 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Baskerville Old Face' (BASKVILL.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,205 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bookman Old Style' (BOOKOSI.TTF) italic normal book normal>) = 11.05
# 2020-10-30 17:53:09,205 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Vivaldi' (VIVALDII.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,205 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Broadway' (BROADW.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,206 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Cambria' (cambriaz.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,206 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Segoe UI' (seguibli.ttf) italic normal black normal>) = 11.525
# 2020-10-30 17:53:09,207 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Sitka Small' (SitkaB.ttc) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,207 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Cooper Black' (COOPBL.TTF) normal normal black normal>) = 10.525
# 2020-10-30 17:53:09,208 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Eras Demi ITC' (ERASDEMI.TTF) normal normal demi normal>) = 10.24
# 2020-10-30 17:53:09,208 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Franklin Gothic Heavy' (FRAHVIT.TTF) italic normal heavy normal>) = 11.43
# 2020-10-30 17:53:09,209 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Segoe UI' (segoeuib.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,210 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Dubai' (DUBAI-BOLD.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,210 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Candara' (Candaraz.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,211 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'SimSun' (simsun.ttc) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,212 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Myanmar Text' (mmrtextb.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,212 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Consolas' (consolai.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,213 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Palatino Linotype' (palabi.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,213 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Wingdings 3' (WINGDNG3.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,213 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Arial' (arial.ttf) normal normal 400 normal>) = 6.413636363636363
# 2020-10-30 17:53:09,213 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Microsoft New Tai Lue' (ntailu.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,215 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Consolas' (consolab.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,215 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Gloucester MT Extra Condensed' (GLECB.TTF) normal normal 400 condensed>) = 10.25
# 2020-10-30 17:53:09,216 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Comic Sans MS' (comici.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,216 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Niagara Solid' (NIAGSOL.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,217 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Calligraphy' (LCALLIG.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,217 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Bright' (LBRITEI.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,218 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Harlow Solid Italic' (HARLOWSI.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,218 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Yu Gothic' (YuGothB.ttc) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,219 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Segoe UI' (seguili.ttf) italic normal light normal>) = 11.24
# 2020-10-30 17:53:09,219 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Calibri' (calibri.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,220 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Niagara Engraved' (NIAGENG.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,220 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'French Script MT' (FRSCRIPT.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,221 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Calibri' (calibriz.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,222 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Elephant' (ELEPHNTI.TTF) italic normal 400 normal>) = 11.05
# ...
# 2020-10-30 17:53:09,385 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Book Antiqua' (ANTQUABI.TTF) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,386 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Rockwell Condensed' (ROCC____.TTF) normal normal 400 condensed>) = 10.25
# 2020-10-30 17:53:09,386 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Leelawadee UI' (LeelUIsl.ttf) normal normal light normal>) = 10.24
# 2020-10-30 17:53:09,387 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bell MT' (BELL.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,388 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Corbel' (corbel.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,388 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Matura MT Script Capitals' (MATURASC.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,389 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Leelawadee' (LEELAWDB.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,389 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'HoloLens MDL2 Assets' (holomdl2.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,390 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Ebrima' (ebrima.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,390 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Gabriola' (Gabriola.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,390 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,391 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bodoni MT' (BOD_R.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,391 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Curlz MT' (CURLZ___.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,392 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Constantia' (constan.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,392 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Courier New' (cour.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,392 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Poor Richard' (POORICH.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,393 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Century Gothic' (GOTHIC.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,394 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Garamond' (GARA.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,394 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Trebuchet MS' (trebucit.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,395 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Goudy Stout' (GOUDYSTO.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,395 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Segoe UI Historic' (seguihis.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,395 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Bright' (LBRITED.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,396 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Malgun Gothic' (malgun.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,396 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bookman Old Style' (BOOKOSI.TTF) italic normal book normal>) = 11.05
# 2020-10-30 17:53:09,397 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Garamond' (GARAIT.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,397 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Verdana' (verdanai.ttf) italic normal 400 normal>) = 4.6863636363636365
# 2020-10-30 17:53:09,398 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Microsoft YaHei' (msyhl.ttc) normal normal light normal>) = 10.24
# 2020-10-30 17:53:09,398 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Corbel' (corbelz.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,398 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Harlow Solid Italic' (HARLOWSI.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,399 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Calisto MT' (CALISTBI.TTF) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,399 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Calibri' (calibriz.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,399 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Copperplate Gothic Bold' (COPRGTB.TTF) normal normal bold normal>) = 10.335
# 2020-10-30 17:53:09,400 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Segoe Print' (segoepr.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,400 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Agency FB' (AGENCYB.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,401 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Sans Unicode' (l_10646.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,401 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Monotype Corsiva' (MTCORSVA.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,402 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Microsoft Yi Baiti' (msyi.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,402 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Juice ITC' (JUICE___.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,403 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Sitka Small' (Sitka.ttc) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,403 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bodoni MT' (BOD_BI.TTF) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,404 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Eras Light ITC' (ERASLGHT.TTF) normal normal light normal>) = 10.24
# 2020-10-30 17:53:09,404 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Garamond' (GARABD.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,405 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Segoe Print' (segoeprb.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,407 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Candara' (Candara.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,407 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Trebuchet MS' (trebuc.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,408 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bookman Old Style' (BOOKOS.TTF) normal normal book normal>) = 10.05
# 2020-10-30 17:53:09,409 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Arial Rounded MT Bold' (ARLRDBD.TTF) normal normal bold normal>) = 10.335
# 2020-10-30 17:53:09,409 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Engravers MT' (ENGR.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,409 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Tempus Sans ITC' (TEMPSITC.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,410 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Microsoft JhengHei' (msjhbd.ttc) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,410 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Corbel' (corbeli.ttf) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,411 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Courier New' (courbd.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,414 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Perpetua Titling MT' (PERTILI.TTF) normal normal light normal>) = 10.24
# 2020-10-30 17:53:09,415 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Myanmar Text' (mmrtext.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,415 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Palatino Linotype' (palabi.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,416 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Gadugi' (gadugi.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,416 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'MS Reference Sans Serif' (REFSAN.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,417 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Cambria' (cambriaz.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,417 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Arial' (ARIALNI.TTF) italic normal 400 condensed>) = 7.613636363636363
# 2020-10-30 17:53:09,418 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Engravers MT' (ENGR.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,418 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Verdana' (verdanab.ttf) normal normal 700 normal>) = 3.9713636363636367
# 2020-10-30 17:53:09,419 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'MS Gothic' (msgothic.ttc) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,420 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Rockwell Condensed' (ROCC____.TTF) normal normal 400 condensed>) = 10.25
# 2020-10-30 17:53:09,420 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Bright' (LBRITEDI.TTF) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,421 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Segoe Print' (segoepr.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,421 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Haettenschweiler' (HATTEN.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,422 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bodoni MT' (BOD_B.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,422 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Microsoft YaHei' (msyh.ttc) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,423 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Perpetua' (PERBI___.TTF) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,423 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Wide Latin' (LATINWD.TTF) normal normal 400 expanded>) = 10.25
# 2020-10-30 17:53:09,424 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Goudy Old Style' (GOUDOSB.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,424 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Tw Cen MT' (TCB_____.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,425 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Agency FB' (AGENCYR.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,425 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Sans' (LSANSDI.TTF) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,425 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Gill Sans MT' (GILI____.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,426 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Footlight MT Light' (FTLTLT.TTF) normal normal light normal>) = 10.24
# 2020-10-30 17:53:09,426 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Bodoni MT' (BOD_CI.TTF) italic normal 400 condensed>) = 11.25
# 2020-10-30 17:53:09,426 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Forte' (FORTE.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,427 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Segoe UI' (seguisb.ttf) normal normal semibold normal>) = 10.24
# 2020-10-30 17:53:09,427 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Georgia' (georgiaz.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,428 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Tw Cen MT' (TCM_____.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,428 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Calibri' (calibrib.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,429 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Franklin Gothic Demi' (FRADMIT.TTF) italic normal demi normal>) = 11.24
# 2020-10-30 17:53:09,429 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Nirmala UI' (NirmalaB.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,430 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Microsoft New Tai Lue' (ntailub.ttf) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,430 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Book Antiqua' (BKANT.TTF) normal normal book normal>) = 10.05
# 2020-10-30 17:53:09,431 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Calisto MT' (CALIST.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,431 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Rockwell' (ROCKI.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,431 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Verdana' (verdanai.ttf) italic normal 400 normal>) = 4.6863636363636365
# 2020-10-30 17:53:09,432 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Courier New' (courbi.ttf) italic normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,432 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Freestyle Script' (FREESCPT.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,432 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Cambria' (cambria.ttc) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,434 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Microsoft Uighur' (MSUIGHUR.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,434 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Gill Sans Ultra Bold' (GILSANUB.TTF) normal normal bold normal>) = 10.335
# 2020-10-30 17:53:09,435 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Mongolian Baiti' (monbaiti.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,435 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Cambria' (cambria.ttc) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,435 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Rockwell' (ROCKB.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,436 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'French Script MT' (FRSCRIPT.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,436 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'MV Boli' (mvboli.ttf) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,437 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Wide Latin' (LATINWD.TTF) normal normal 400 expanded>) = 10.25
# 2020-10-30 17:53:09,438 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Calisto MT' (CALISTI.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,438 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Gigi' (GIGI.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,439 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEBO.TTF) oblique normal 700 normal>) = 11.335
# 2020-10-30 17:53:09,440 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Book Antiqua' (ANTQUAB.TTF) normal normal 700 normal>) = 10.335
# 2020-10-30 17:53:09,441 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'MT Extra' (MTEXTRA.TTF) normal normal 400 normal>) = 10.05
# 2020-10-30 17:53:09,441 - matplotlib.font_manager - DEBUG - findfont: score(<Font 'Brush Script MT' (BRUSHSCI.TTF) italic normal 400 normal>) = 11.05
# 2020-10-30 17:53:09,442 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('C:\\Users\\MathildeElimas\\anaconda3\\envs\\tf\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000.

# %% [markdown]
# #### create vocabulary & output labels

# %%
idx, cleaned_words = clean_sentences(sentences)
word_tokenizer = create_tokenizer(cleaned_words)

vocab_size = len(word_tokenizer.word_index) + 1
max_length = len(max(cleaned_words, key = len))

print("Vocab Size = %d and Maximum length = %d" % (vocab_size, max_length))
# Out:
# 2020-10-30 17:53:32,898 - spacy_lefff.lefff - INFO - New LefffLemmatizer instantiated.
# 2020-10-30 17:53:32,900 - spacy_lefff.lefff - INFO - Reading lefff data...
# 2020-10-30 17:53:33,887 - spacy_lefff.lefff - INFO - Successfully loaded lefff lemmatizer
# Vocab Size = 1684 and Maximum length = 291

# %%
vocab = create_vocabulary(cleaned_words)
len(vocab)
# Out:
# 2020-10-30 17:54:40,736 - numexpr.utils - INFO - NumExpr defaulting to 8 threads.
# 139

# %%
output_tokenizer = create_tokenizer(unique_intent, filters = '')
output_tokenizer.word_index
# Out:
# {'probleme_box_tv': 1, 'reseau_mobile': 2, 'explication_facture': 3}

# %%
intent = list(map(intent.__getitem__, idx))

encoded_output = intent_embedding(intent)
encoded_output = np.array(encoded_output) 

encoded_output.shape
# Out:
# (2,)

# %% [markdown]
# ### Boosting model

# %% [markdown]
# #### Train/Test

# %%
Y = [output_tokenizer.word_index[intent.lower()] for intent in intent]

# %%
if method == 'tfidf':
    Tfidf_vect = TfidfVectorizer(max_features=5000, vocabulary = list(vocab.keys()))
    Tfidf_vect.fit(cleaned_words)

    X = Tfidf_vect.transform(cleaned_words)
elif method == 'count':
    Count_vect = CountVectorizer(max_features=5000, vocabulary = list(vocab.keys()))
    Count_vect.fit(cleaned_words)

    X = Count_vect.transform(cleaned_words)

# %%
Train_X, Test_X, Train_Y, Test_Y = train_test_split(X, Y,test_size=0.2, random_state = 123)

# %% [markdown]
# #### Model definition & training

# %%
k_fold = KFold(n_splits=100)

# %%
# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
boost = GradientBoostingClassifier()

cv = cross_validate(boost, X, Y, cv = k_fold, scoring = 'balanced_accuracy')
boost.fit(Train_X,Train_Y)
# Out:
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# C:\Users\MathildeElimas\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\classification.py:1745: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
with open(os.getcwd().replace('\\models', '') + '\\resultats\\boosting_' + method +'.pkl','wb') as f:
    pickle.dump(boost,f)

# %%
cv['test_score'].mean()
# Out:
# 0.6949712643678161

# %% [markdown]
# #### Model evaluation

# %% [markdown]
# Test with test dataset

# %%
# predict the labels on validation dataset
predictions_boosting = boost.predict(Test_X)
# Use accuracy_score function to get the accuracy
print("Boosting Accuracy Score -> ", balanced_accuracy_score(Test_Y, predictions_boosting)*100)
# Out:
# Boosting Accuracy Score ->  71.45238185088746

# %% [markdown]
# Test with a sentence

# %%
text = "J'ai un problème avec ma box."
# pred = int(boost.predict(Tfidf_vect.transform([text])))
pred = int(boost.predict(Count_vect.transform([text])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-49766a2f687e> in <module>
#       1 text = "J'ai un problème avec ma box."
#       2 # pred = int(boost.predict(Tfidf_vect.transform([text])))
# ----> 3 pred = int(boost.predict(Count_vect.transform([text])))
#
# NameError: name 'Count_vect' is not defined

# %%
output_tokenizer.index_word[pred]
